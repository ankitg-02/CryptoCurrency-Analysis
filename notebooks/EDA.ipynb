# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = "data/BTC_USD_daily_transformed.csv"
df = pd.read_csv(data_path)
df['time'] = pd.to_datetime(df['time'])
df.head()
# Out:
# File not found: BTC_USD_daily.csv
